# %%
pwd
# Out:
# 'C:\\Users\\gupta528'

# %%
cd D:
# Out:
# D:\

# %%
cd "D:\Group 1\Data"
# Out:
# D:\Group 1\Data

# %%
import pandas as pd


#test = pd.read_csv("test_v2.csv", nrows = 11000)

# %%
import numpy as np
#np.transpose(test.head())

# %%
test = pd.read_csv("test_v2.csv", low_memory = False, dtype = "str")

# %%
train = pd.read_csv("train_v2.csv", low_memory = False, dtype = "str")

# %%
train2 = train.drop(['hits', 'customDimensions', 'device', 'geoNetwork', 'totals', 'trafficSource'], axis =1)

# %%
train2.head()
# Out:
#   channelGrouping      date        fullVisitorId  socialEngagementType  \
# 0  Organic Search  20171016  3162355547410993243  Not Socially Engaged
# 1        Referral  20171016  8934116514970143966  Not Socially Engaged
# 2          Direct  20171016  7992466427990357681  Not Socially Engaged
# 3  Organic Search  20171016  9075655783635761930  Not Socially Engaged
# 4  Organic Search  20171016  6960673291025684308  Not Socially Engaged
#
#       visitId visitNumber visitStartTime
# 0  1508198450           1     1508198450
# 1  1508176307           6     1508176307
# 2  1508201613           1     1508201613
# 3  1508169851           1     1508169851
# 4  1508190552           1     1508190552

# %%
import json

# %%
from pandas.io.json import json_normalize

# %%
train_device = json_normalize(train.device.apply(json.loads))

# %%
train_device.head()
# Out:
#    browser                    browserSize                 browserVersion  \
# 0  Firefox  not available in demo dataset  not available in demo dataset
# 1   Chrome  not available in demo dataset  not available in demo dataset
# 2   Chrome  not available in demo dataset  not available in demo dataset
# 3   Chrome  not available in demo dataset  not available in demo dataset
# 4   Chrome  not available in demo dataset  not available in demo dataset
#
#   deviceCategory                   flashVersion  isMobile  \
# 0        desktop  not available in demo dataset     False
# 1        desktop  not available in demo dataset     False
# 2         mobile  not available in demo dataset      True
# 3        desktop  not available in demo dataset     False
# 4        desktop  not available in demo dataset     False
#
#                         language           mobileDeviceBranding  \
# 0  not available in demo dataset  not available in demo dataset
# ...

# %%
train_geoNetwork = json_normalize(train.geoNetwork.apply(json.loads))

# %%
train_geoNetwork.head()
# Out:
#                             city                         cityId continent  \
# 0  not available in demo dataset  not available in demo dataset    Europe
# 1                      Cupertino  not available in demo dataset  Americas
# 2  not available in demo dataset  not available in demo dataset  Americas
# 3  not available in demo dataset  not available in demo dataset      Asia
# 4  not available in demo dataset  not available in demo dataset  Americas
#
#          country                       latitude  \
# 0        Germany  not available in demo dataset
# 1  United States  not available in demo dataset
# 2  United States  not available in demo dataset
# 3         Turkey  not available in demo dataset
# 4         Mexico  not available in demo dataset
#
#                        longitude                              metro  \
# 0  not available in demo dataset      not available in demo dataset
# 1  not available in demo dataset  San Francisco-Oakland-San Jose CA
# ...

# %%
#train_device.to_csv("train_device.csv")
#train_geoNetwork.to_csv("train_geo.csv")

# %%
train_totals = json_normalize(train.totals.apply(json.loads))

# %%
train_totals.head()
# Out:
#   bounces hits newVisits pageviews sessionQualityDim timeOnSite  \
# 0       1    1         1         1                 1        NaN
# 1     NaN    2       NaN         2                 2         28
# 2     NaN    2         1         2                 1         38
# 3     NaN    2         1         2                 1          1
# 4     NaN    2         1         2                 1         52
#
#   totalTransactionRevenue transactionRevenue transactions visits
# 0                     NaN                NaN          NaN      1
# 1                     NaN                NaN          NaN      1
# 2                     NaN                NaN          NaN      1
# 3                     NaN                NaN          NaN      1
# 4                     NaN                NaN          NaN      1

# %%
train_traffic = json_normalize(train.trafficSource.apply(json.loads))

# %%
train_traffic.head()
# Out:
#   adContent adwordsClickInfo.adNetworkType  \
# 0       NaN                            NaN
# 1       NaN                            NaN
# 2       NaN                            NaN
# 3       NaN                            NaN
# 4       NaN                            NaN
#
#   adwordsClickInfo.criteriaParameters adwordsClickInfo.gclId  \
# 0       not available in demo dataset                    NaN
# 1       not available in demo dataset                    NaN
# 2       not available in demo dataset                    NaN
# 3       not available in demo dataset                    NaN
# 4       not available in demo dataset                    NaN
#
#   adwordsClickInfo.isVideoAd adwordsClickInfo.page adwordsClickInfo.slot  \
# 0                        NaN                   NaN                   NaN
# 1                        NaN                   NaN                   NaN
# 2                        NaN                   NaN                   NaN
# ...

# %%
#train_totals.to_csv("train_totals.csv")

# %%
#train_traffic.to_csv("train_trafficSource.csv")

# %%
train_device.shape,train_totals.shape,train_geoNetwork.shape,train_traffic.shape
# Out:
# ((1708337, 16), (1708337, 10), (1708337, 11), (1708337, 14))

# %%
frames = [train2, train_device.reset_index(), train_geoNetwork.reset_index(),
          train_totals.reset_index(), train_traffic.reset_index()]

# %%
train_exploded  = pd.concat(frames, axis = 1)

# %%
train_exploded.head()
# Out:
#   channelGrouping      date        fullVisitorId  socialEngagementType  \
# 0  Organic Search  20171016  3162355547410993243  Not Socially Engaged
# 1        Referral  20171016  8934116514970143966  Not Socially Engaged
# 2          Direct  20171016  7992466427990357681  Not Socially Engaged
# 3  Organic Search  20171016  9075655783635761930  Not Socially Engaged
# 4  Organic Search  20171016  6960673291025684308  Not Socially Engaged
#
#       visitId visitNumber visitStartTime  index  browser  \
# 0  1508198450           1     1508198450      0  Firefox
# 1  1508176307           6     1508176307      1   Chrome
# 2  1508201613           1     1508201613      2   Chrome
# 3  1508169851           1     1508169851      3   Chrome
# 4  1508190552           1     1508190552      4   Chrome
#
#                      browserSize  ... adwordsClickInfo.isVideoAd  \
# 0  not available in demo dataset  ...                        NaN
# ...

# %%
train_exploded.shape
# Out:
# (1708337, 62)

# %%
pd.Series(train_exploded.dtypes)[:]
# Out:
# channelGrouping                        object
# date                                   object
# fullVisitorId                          object
# socialEngagementType                   object
# visitId                                object
# visitNumber                            object
# visitStartTime                         object
# index                                   int64
# browser                                object
# browserSize                            object
# browserVersion                         object
# deviceCategory                         object
# flashVersion                           object
# isMobile                                 bool
# language                               object
# mobileDeviceBranding                   object
# mobileDeviceInfo                       object
# mobileDeviceMarketingName              object
# mobileDeviceModel                      object
# mobileInputSelector                    object
# ...

# %%
train_exploded2 = train_exploded.drop('index', axis = 1)

# %%
train_exploded2.head()
# Out:
#   channelGrouping      date        fullVisitorId  socialEngagementType  \
# 0  Organic Search  20171016  3162355547410993243  Not Socially Engaged
# 1        Referral  20171016  8934116514970143966  Not Socially Engaged
# 2          Direct  20171016  7992466427990357681  Not Socially Engaged
# 3  Organic Search  20171016  9075655783635761930  Not Socially Engaged
# 4  Organic Search  20171016  6960673291025684308  Not Socially Engaged
#
#       visitId visitNumber visitStartTime  browser  \
# 0  1508198450           1     1508198450  Firefox
# 1  1508176307           6     1508176307   Chrome
# 2  1508201613           1     1508201613   Chrome
# 3  1508169851           1     1508169851   Chrome
# 4  1508190552           1     1508190552   Chrome
#
#                      browserSize                 browserVersion  ...  \
# 0  not available in demo dataset  not available in demo dataset  ...
# 1  not available in demo dataset  not available in demo dataset  ...
# ...

# %%
train_exploded2.dtypes
# Out:
# channelGrouping                        object
# date                                   object
# fullVisitorId                          object
# socialEngagementType                   object
# visitId                                object
# visitNumber                            object
# visitStartTime                         object
# browser                                object
# browserSize                            object
# browserVersion                         object
# deviceCategory                         object
# flashVersion                           object
# isMobile                                 bool
# language                               object
# mobileDeviceBranding                   object
# mobileDeviceInfo                       object
# mobileDeviceMarketingName              object
# mobileDeviceModel                      object
# mobileInputSelector                    object
# operatingSystem                        object
# ...

# %%
#train_exploded.to_csv("train_exploded.csv")

# %% [raw]
# trainx = train.drop('hits', axis = 1)
# trainxx = trainx.drop('geoNetwork', axis = 1)
# trainxxx = trainxx.drop('trafficSource', axis = 1)
# trainyyy = trainxxx.drop('totals', axis = 1)
# trainyy = trainyyy.drop('customDimensions', axis = 1)
# trainy = trainyy.drop('device',axis = 1)

# %% [raw]
# frame2 = [trainy, train_exploded]

# %% [raw]
# final_train = pd.concat(frame2, axis = 1)

# %% [raw]
# final_train.shape

# %% [raw]
# final_train.to_csv("final_train.csv")

# %% [raw]
# final_train.loc[10:100]

# %% [raw]
# final_train.columns

# %% [raw]
# final2 = final_train.drop(['level_0', 'index'],axis = 1)

# %% [raw]
# final2.columns.size

# %% [raw]
# final2.columns.unique().size

# %%
train_exploded2.to_csv("trainv2_wo_hitsDim.csv")

# %% [markdown]
# -------

# %% [markdown]
# -------

# %% [markdown]
# <h2> Test </h2>

# %%
test.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'APAC'}]  20180511
# 1          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 2  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
# 3          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 4  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  7460955084541987166
# 1  {"browser": "Chrome", "browserVersion": "not a...   460252456180441002
# 2  {"browser": "Chrome", "browserVersion": "not a...  3461808543879602873
# 3  {"browser": "Chrome", "browserVersion": "not a...   975129477712150630
# 4  {"browser": "Internet Explorer", "browserVersi...  8381672768065729990
#
#                                           geoNetwork  \
# ...

# %%
test_device = json_normalize(test.device.apply(json.loads))
test_geoNetwork = json_normalize(test.geoNetwork.apply(json.loads))
test_totals = json_normalize(test.totals.apply(json.loads))
test_traffic = json_normalize(test.trafficSource.apply(json.loads))

# %%
test2 = test.drop(['hits', 'geoNetwork', 'totals', 'trafficSource', 'device', 'customDimensions'], axis = 1)

# %%
test_frame = [test2, test_device.reset_index(),
              test_geoNetwork.reset_index(), test_totals.reset_index(), test_traffic.reset_index() ]

# %%
test_exploded = pd.concat(test_frame, axis = 1)

# %%
test_exploded.head()
# Out:
#   channelGrouping      date        fullVisitorId  socialEngagementType  \
# 0  Organic Search  20180511  7460955084541987166  Not Socially Engaged
# 1          Direct  20180511   460252456180441002  Not Socially Engaged
# 2  Organic Search  20180511  3461808543879602873  Not Socially Engaged
# 3          Direct  20180511   975129477712150630  Not Socially Engaged
# 4  Organic Search  20180511  8381672768065729990  Not Socially Engaged
#
#       visitId visitNumber visitStartTime  index            browser  \
# 0  1526099341           2     1526099341      0             Chrome
# 1  1526064483         166     1526064483      1             Chrome
# 2  1526067157           2     1526067157      2             Chrome
# 3  1526107551           4     1526107551      3             Chrome
# 4  1526060254           1     1526060254      4  Internet Explorer
#
#                      browserSize  ... adwordsClickInfo.gclId  \
# 0  not available in demo dataset  ...                    NaN
# ...

# %%
test_exploded.dtypes
# Out:
# channelGrouping                        object
# date                                   object
# fullVisitorId                          object
# socialEngagementType                   object
# visitId                                object
# visitNumber                            object
# visitStartTime                         object
# index                                   int64
# browser                                object
# browserSize                            object
# browserVersion                         object
# deviceCategory                         object
# flashVersion                           object
# isMobile                                 bool
# language                               object
# mobileDeviceBranding                   object
# mobileDeviceInfo                       object
# mobileDeviceMarketingName              object
# mobileDeviceModel                      object
# mobileInputSelector                    object
# ...

# %%
test_exploded2 = test_exploded.drop('index',axis = 1)

# %%
test_exploded2.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'socialEngagementType',
#        'visitId', 'visitNumber', 'visitStartTime', 'browser', 'browserSize',
#        'browserVersion', 'deviceCategory', 'flashVersion', 'isMobile',
#        'language', 'mobileDeviceBranding', 'mobileDeviceInfo',
#        'mobileDeviceMarketingName', 'mobileDeviceModel', 'mobileInputSelector',
#        'operatingSystem', 'operatingSystemVersion', 'screenColors',
#        'screenResolution', 'city', 'cityId', 'continent', 'country',
#        'latitude', 'longitude', 'metro', 'networkDomain', 'networkLocation',
#        'region', 'subContinent', 'bounces', 'hits', 'newVisits', 'pageviews',
#        'sessionQualityDim', 'timeOnSite', 'totalTransactionRevenue',
#        'transactionRevenue', 'transactions', 'visits', 'adContent',
#        'adwordsClickInfo.adNetworkType', 'adwordsClickInfo.criteriaParameters',
#        'adwordsClickInfo.gclId', 'adwordsClickInfo.isVideoAd',
# ...

# %%
train_exploded2.shape
# Out:
# (1708337, 58)

# %%
test_exploded2.shape
# Out:
# (401589, 57)

# %% [markdown]
# <i><b>Test dataset does not have CampaignCode field </b></i>

# %%
test_exploded2.to_csv("testv2_wo_hitsDim.csv")

# %% [markdown]
# <h4><u> Data Validation checks </u></h4>

# %%
gtrain = pd.read_csv("trainv2_wo_hitsDim.csv")
gtest = pd.read_csv("testv2_wo_hitsDim.csv")
print("Loaded train and test")
# Out:
# Loaded train and test

# %%
pd.DataFrame(gtrain.dtypes,gtrain.columns, columns = ["train_dtype"])
# Out:
#                                     train_dtype
# Unnamed: 0                                int64
# channelGrouping                          object
# date                                      int64
# fullVisitorId                            object
# socialEngagementType                     object
# visitId                                   int64
# visitNumber                               int64
# visitStartTime                            int64
# browser                                  object
# browserSize                              object
# browserVersion                           object
# deviceCategory                           object
# flashVersion                             object
# isMobile                                   bool
# language                                 object
# mobileDeviceBranding                     object
# mobileDeviceInfo                         object
# mobileDeviceMarketingName                object
# mobileDeviceModel                        object
# ...

# %%
pd.DataFrame(gtest.dtypes,gtest.columns,columns = ["test_dtype"])
# Out:
#                                     test_dtype
# Unnamed: 0                               int64
# channelGrouping                         object
# date                                     int64
# fullVisitorId                           object
# socialEngagementType                    object
# visitId                                  int64
# visitNumber                              int64
# visitStartTime                           int64
# browser                                 object
# browserSize                             object
# browserVersion                          object
# deviceCategory                          object
# flashVersion                            object
# isMobile                                  bool
# language                                object
# mobileDeviceBranding                    object
# mobileDeviceInfo                        object
# mobileDeviceMarketingName               object
# mobileDeviceModel                       object
# ...

# %%
gtrain.columns.size,gtest.columns.size
# Out:
# (59, 58)

# %%
gtrain.columns[gtrain.columns[pd.Series(gtrain.columns).isin(gtest.columns).index.values].isin(gtest.columns)==False]
# Out:
# Index(['campaignCode'], dtype='object')

# %% [markdown]
# <b>Campanign Code not in test, present in train </b>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = [20,12])

plt.plot( gtrain.index,(np.log1p(gtrain.transactionRevenue)), "black")
plt.plot( gtrain.index,(np.log1p(gtrain.totalTransactionRevenue)-(np.log1p(gtrain.transactionRevenue))), "green")

plt.ylabel("Log transaction amount")
plt.xlabel("row number")
plt.title("Train Transaction Revenue")
plt.show()
# Out:
# C:\Python\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log1p
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log1p
#   after removing the cwd from sys.path.

# %%
plt.figure(figsize = [20,12])

plt.plot( gtest.index,(np.log1p(gtest.transactionRevenue)), "blue")
plt.plot( gtest.index,(np.log1p(gtest.totalTransactionRevenue)-(np.log1p(gtest.transactionRevenue))), "green")

plt.ylabel(" Log transaction amount")
plt.xlabel("row number")
plt.title("Test log Transaction Revenue")
plt.show()
# Out:
# C:\Python\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log1p
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log1p
#   after removing the cwd from sys.path.

# %%
train_miss = pd.DataFrame(gtrain.isna().sum(),gtrain.columns, columns = ["missings"])
train_miss["miss_perc"] = train_miss.missings*100/train.date.size
train_miss
# Out:
#                                      missings  miss_perc
# Unnamed: 0                                  0   0.000000
# channelGrouping                             0   0.000000
# date                                        0   0.000000
# fullVisitorId                               0   0.000000
# socialEngagementType                        0   0.000000
# visitId                                     0   0.000000
# visitNumber                                 0   0.000000
# visitStartTime                              0   0.000000
# browser                                     0   0.000000
# browserSize                                 0   0.000000
# browserVersion                              0   0.000000
# deviceCategory                              0   0.000000
# flashVersion                                0   0.000000
# isMobile                                    0   0.000000
# language                                    0   0.000000
# ...

# %%
columns_to_drop = []
for each in gtrain.columns:
    print(each,gtrain[each].nunique(dropna=False))
    if gtrain[each].nunique(dropna=False) ==1:
        columns_to_drop.append(each)
        print ("{} will be dropped".format(each))
# Out:
# Unnamed: 0 1708337
# channelGrouping 8
# date 638
# fullVisitorId 1371486
# socialEngagementType 1
# socialEngagementType will be dropped
# visitId 1665802
# visitNumber 457
# visitStartTime 1667423
# browser 129
# browserSize 1
# browserSize will be dropped
# browserVersion 1
# browserVersion will be dropped
# deviceCategory 3
# flashVersion 1
# flashVersion will be dropped
# isMobile 2
# language 1
# language will be dropped
# mobileDeviceBranding 1
# mobileDeviceBranding will be dropped
# mobileDeviceInfo 1
# mobileDeviceInfo will be dropped
# mobileDeviceMarketingName 1
# mobileDeviceMarketingName will be dropped
# mobileDeviceModel 1
# mobileDeviceModel will be dropped
# mobileInputSelector 1
# mobileInputSelector will be dropped
# operatingSystem 24
# operatingSystemVersion 1
# operatingSystemVersion will be dropped
# screenColors 1
# screenColors will be dropped
# screenResolution 1
# screenResolution will be dropped
# city 956
# cityId 1
# cityId will be dropped
# ...

# %%
len(columns_to_drop)
# Out:
# 19

# %%
gtrain_dropped1 = gtrain.drop(columns_to_drop, axis = 1)

# %%
gtest_dropped1 = gtest.drop(columns_to_drop, axis = 1)

# %%
gtrain_dropped1.columns
# Out:
# Index(['Unnamed: 0', 'channelGrouping', 'date', 'fullVisitorId', 'visitId',
#        'visitNumber', 'visitStartTime', 'browser', 'deviceCategory',
#        'isMobile', 'operatingSystem', 'city', 'continent', 'country', 'metro',
#        'networkDomain', 'region', 'subContinent', 'bounces', 'hits',
#        'newVisits', 'pageviews', 'sessionQualityDim', 'timeOnSite',
#        'totalTransactionRevenue', 'transactionRevenue', 'transactions',
#        'adContent', 'adwordsClickInfo.adNetworkType', 'adwordsClickInfo.gclId',
#        'adwordsClickInfo.isVideoAd', 'adwordsClickInfo.page',
#        'adwordsClickInfo.slot', 'campaign', 'campaignCode', 'isTrueDirect',
#        'keyword', 'medium', 'referralPath', 'source'],
#       dtype='object')

# %%
gtest_dropped1.columns
# Out:
# Index(['Unnamed: 0', 'channelGrouping', 'date', 'fullVisitorId', 'visitId',
#        'visitNumber', 'visitStartTime', 'browser', 'deviceCategory',
#        'isMobile', 'operatingSystem', 'city', 'continent', 'country', 'metro',
#        'networkDomain', 'region', 'subContinent', 'bounces', 'hits',
#        'newVisits', 'pageviews', 'sessionQualityDim', 'timeOnSite',
#        'totalTransactionRevenue', 'transactionRevenue', 'transactions',
#        'adContent', 'adwordsClickInfo.adNetworkType', 'adwordsClickInfo.gclId',
#        'adwordsClickInfo.isVideoAd', 'adwordsClickInfo.page',
#        'adwordsClickInfo.slot', 'campaign', 'isTrueDirect', 'keyword',
#        'medium', 'referralPath', 'source'],
#       dtype='object')

# %%
gtrain_dropped1.head()
# Out:
#   channelGrouping      date        fullVisitorId     visitId  visitNumber  \
# 0  Organic Search  20171016  3162355547410993243  1508198450            1
# 1        Referral  20171016  8934116514970143966  1508176307            6
# 2          Direct  20171016  7992466427990357681  1508201613            1
# 3  Organic Search  20171016  9075655783635761930  1508169851            1
# 4  Organic Search  20171016  6960673291025684308  1508190552            1
#
#    visitStartTime  browser deviceCategory  isMobile operatingSystem  ...  \
# 0      1508198450  Firefox        desktop     False         Windows  ...
# 1      1508176307   Chrome        desktop     False       Chrome OS  ...
# 2      1508201613   Chrome         mobile      True         Android  ...
# 3      1508169851   Chrome        desktop     False         Windows  ...
# 4      1508190552   Chrome        desktop     False         Windows  ...
#
#   adwordsClickInfo.isVideoAd adwordsClickInfo.page adwordsClickInfo.slot  \
# ...

# %%
gtest_dropped1.head()
# Out:
#   channelGrouping      date        fullVisitorId     visitId  visitNumber  \
# 0  Organic Search  20180511  7460955084541987166  1526099341            2
# 1          Direct  20180511   460252456180441002  1526064483          166
# 2  Organic Search  20180511  3461808543879602873  1526067157            2
# 3          Direct  20180511   975129477712150630  1526107551            4
# 4  Organic Search  20180511  8381672768065729990  1526060254            1
#
#    visitStartTime            browser deviceCategory  isMobile operatingSystem  \
# 0      1526099341             Chrome         mobile      True         Android
# 1      1526064483             Chrome        desktop     False       Macintosh
# 2      1526067157             Chrome        desktop     False       Chrome OS
# 3      1526107551             Chrome         mobile      True             iOS
# 4      1526060254  Internet Explorer         tablet      True         Windows
#
# ...

# %%
gtrain_dropped1.drop("Unnamed: 0",axis = 1, inplace = True)

# %%
gtest_dropped1.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
gtrain_dropped1.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'visitId', 'visitNumber',
#        'visitStartTime', 'browser', 'deviceCategory', 'isMobile',
#        'operatingSystem', 'city', 'continent', 'country', 'metro',
#        'networkDomain', 'region', 'subContinent', 'bounces', 'hits',
#        'newVisits', 'pageviews', 'sessionQualityDim', 'timeOnSite',
#        'totalTransactionRevenue', 'transactionRevenue', 'transactions',
#        'adContent', 'adwordsClickInfo.adNetworkType', 'adwordsClickInfo.gclId',
#        'adwordsClickInfo.isVideoAd', 'adwordsClickInfo.page',
#        'adwordsClickInfo.slot', 'campaign', 'campaignCode', 'isTrueDirect',
#        'keyword', 'medium', 'referralPath', 'source'],
#       dtype='object')

# %%
gtrain_dropped1.head()
# Out:
#   channelGrouping      date        fullVisitorId     visitId  visitNumber  \
# 0  Organic Search  20171016  3162355547410993243  1508198450            1
# 1        Referral  20171016  8934116514970143966  1508176307            6
# 2          Direct  20171016  7992466427990357681  1508201613            1
# 3  Organic Search  20171016  9075655783635761930  1508169851            1
# 4  Organic Search  20171016  6960673291025684308  1508190552            1
#
#    visitStartTime  browser deviceCategory  isMobile operatingSystem  ...  \
# 0      1508198450  Firefox        desktop     False         Windows  ...
# 1      1508176307   Chrome        desktop     False       Chrome OS  ...
# 2      1508201613   Chrome         mobile      True         Android  ...
# 3      1508169851   Chrome        desktop     False         Windows  ...
# 4      1508190552   Chrome        desktop     False         Windows  ...
#
#   adwordsClickInfo.isVideoAd adwordsClickInfo.page adwordsClickInfo.slot  \
# ...

# %%
train_dropped_miss = pd.DataFrame(gtrain_dropped1.isna().sum(),gtrain_dropped1.columns, columns = ["missings"])

train_dropped_miss["miss_perc"] = train_dropped_miss.missings*100/gtrain_dropped1.date.size
train_dropped_miss
# Out:
#                                 missings  miss_perc
# channelGrouping                        0   0.000000
# date                                   0   0.000000
# fullVisitorId                          0   0.000000
# visitId                                0   0.000000
# visitNumber                            0   0.000000
# visitStartTime                         0   0.000000
# browser                                0   0.000000
# deviceCategory                         0   0.000000
# isMobile                               0   0.000000
# operatingSystem                        0   0.000000
# city                                   0   0.000000
# continent                              0   0.000000
# country                                0   0.000000
# metro                                  0   0.000000
# networkDomain                          0   0.000000
# region                                 0   0.000000
# subContinent                           0   0.000000
# ...

# %%
test_dropped_miss = pd.DataFrame(gtest_dropped1.isna().sum(),gtest_dropped1.columns, columns = ["missings"])

test_dropped_miss["miss_perc"] = test_dropped_miss.missings*100/gtest_dropped1.date.size
test_dropped_miss
# Out:
#                                 missings  miss_perc
# channelGrouping                        0   0.000000
# date                                   0   0.000000
# fullVisitorId                          0   0.000000
# visitId                                0   0.000000
# visitNumber                            0   0.000000
# visitStartTime                         0   0.000000
# browser                                0   0.000000
# deviceCategory                         0   0.000000
# isMobile                               0   0.000000
# operatingSystem                        0   0.000000
# city                                   0   0.000000
# continent                              0   0.000000
# country                                0   0.000000
# metro                                  0   0.000000
# networkDomain                          0   0.000000
# region                                 0   0.000000
# subContinent                           0   0.000000
# ...

# %%
plt.figure(figsize = [12,12])
plt.barh(train_dropped_miss.miss_perc.sort_values().index,train_dropped_miss.miss_perc.sort_values().values)

plt.title("Missing values in Train")
plt.show()

# %%
plt.figure(figsize = [12,10])
plt.barh(test_dropped_miss.miss_perc.sort_values().index,test_dropped_miss.miss_perc.sort_values().values)

plt.title("Missing values in Test")
plt.show()

# %%
gtrain_dropped1.dtypes
# Out:
# channelGrouping                    object
# date                                int64
# fullVisitorId                      object
# visitId                             int64
# visitNumber                         int64
# visitStartTime                      int64
# browser                            object
# deviceCategory                     object
# isMobile                             bool
# operatingSystem                    object
# city                               object
# continent                          object
# country                            object
# metro                              object
# networkDomain                      object
# region                             object
# subContinent                       object
# bounces                           float64
# hits                                int64
# newVisits                         float64
# pageviews                         float64
# sessionQualityDim                 float64
# ...

# %%
gtrain_dropped1.drop("campaignCode", axis = 1, inplace = True)

# %%
gtrain_w_revenue = gtrain_dropped1[gtrain_dropped1.transactionRevenue > 0]

# %%
gtrain_w_revenue.head()
# Out:
#     channelGrouping      date        fullVisitorId     visitId  visitNumber  \
# 433  Organic Search  20171016  9549826748224805897  1508200705            4
# 550        Referral  20171016  3700714855829972615  1508192636           11
# 555  Organic Search  20171016  1572225825161580042  1508162218            6
# 597        Referral  20171016  7187192533100162289  1508189401           17
# 619        Referral  20171016  7889233516776348524  1508190484            1
#
#      visitStartTime browser deviceCategory  isMobile operatingSystem  ...  \
# 433      1508200705  Chrome        desktop     False       Macintosh  ...
# 550      1508192636  Chrome        desktop     False         Windows  ...
# 555      1508162218  Safari         mobile      True             iOS  ...
# 597      1508189401  Chrome        desktop     False       Macintosh  ...
# 619      1508190484  Chrome        desktop     False       Macintosh  ...
#
# ...

# %%
gtest_w_revenue = gtest_dropped1[gtest_dropped1.transactionRevenue > 0]
gtest_w_revenue.head()
# Out:
#     channelGrouping      date        fullVisitorId     visitId  visitNumber  \
# 268          Direct  20180511   567632072087918290  1526043913            1
# 353  Organic Search  20180511    34941760139500427  1526090105            1
# 369          Direct  20180511  7417113168654151999  1526052977            1
# 381        Referral  20180511  5963345090934142475  1526051906            3
# 391  Organic Search  20180511  6525673967695077450  1526098702            1
#
#      visitStartTime browser deviceCategory  isMobile operatingSystem  ...  \
# 268      1526043913  Chrome        desktop     False       Chrome OS  ...
# 353      1526090105  Chrome        desktop     False       Macintosh  ...
# 369      1526052977  Chrome        desktop     False         Windows  ...
# 381      1526051906  Chrome        desktop     False       Macintosh  ...
# 391      1526098702  Chrome         mobile      True         Android  ...
#
# ...

# %%
train_wrev_miss = pd.DataFrame(gtrain_w_revenue.isna().sum(),gtrain_w_revenue.columns, columns = ["missings"])

train_wrev_miss["miss_perc"] = train_wrev_miss.missings*100/gtrain_w_revenue.date.size
train_wrev_miss
# Out:
#                                 missings   miss_perc
# channelGrouping                        0    0.000000
# date                                   0    0.000000
# fullVisitorId                          0    0.000000
# visitId                                0    0.000000
# visitNumber                            0    0.000000
# visitStartTime                         0    0.000000
# browser                                0    0.000000
# deviceCategory                         0    0.000000
# isMobile                               0    0.000000
# operatingSystem                        0    0.000000
# city                                   0    0.000000
# continent                              0    0.000000
# country                                0    0.000000
# metro                                  0    0.000000
# networkDomain                          0    0.000000
# region                                 0    0.000000
# subContinent                           0    0.000000
# ...

# %%
test_wrev_miss = pd.DataFrame(gtest_w_revenue.isna().sum(),gtest_w_revenue.columns, columns = ["missings"])

test_wrev_miss["miss_perc"] = test_wrev_miss.missings*100/gtest_w_revenue.date.size
test_wrev_miss
# Out:
#                                 missings   miss_perc
# channelGrouping                        0    0.000000
# date                                   0    0.000000
# fullVisitorId                          0    0.000000
# visitId                                0    0.000000
# visitNumber                            0    0.000000
# visitStartTime                         0    0.000000
# browser                                0    0.000000
# deviceCategory                         0    0.000000
# isMobile                               0    0.000000
# operatingSystem                        0    0.000000
# city                                   0    0.000000
# continent                              0    0.000000
# country                                0    0.000000
# metro                                  0    0.000000
# networkDomain                          0    0.000000
# region                                 0    0.000000
# subContinent                           0    0.000000
# ...

# %%
plt.figure(figsize = [12,12])
plt.barh(train_wrev_miss.miss_perc.sort_values().index,train_wrev_miss.miss_perc.sort_values().values)

plt.title("Missing values in Train with Revenue")
plt.show()

# %%
plt.figure(figsize = [12,10])
plt.barh(test_wrev_miss.miss_perc.sort_values().index,test_wrev_miss.miss_perc.sort_values().values)

plt.title("Missing values in Test with Revenue")
plt.show()

# %% [markdown]
# <b>Modelling </b>

# %%
train_df = gtrain_dropped1

# %%
test_df = gtest_dropped1

# %%
from sklearn.preprocessing import LabelEncoder

cat_cols = ["channelGrouping", "browser", 
            "deviceCategory", "operatingSystem", 
            "city", "continent", 
            "country", "metro",
            "networkDomain", "region", 
            "subContinent", "adContent", 
            "adwordsClickInfo.adNetworkType", 
            "adwordsClickInfo.gclId", 
            "adwordsClickInfo.page", 
            "adwordsClickInfo.slot", "campaign",
            "keyword", "medium", 
            "referralPath", "source",
            'adwordsClickInfo.isVideoAd', 'isTrueDirect']


for col in cat_cols:
    print(col)
    lbl = LabelEncoder()
    lbl.fit(list(train_df[col].values.astype('str'))) # + list(test_df[col].values.astype('str')))
    train_df[col] = lbl.transform(list(train_df[col].values.astype('str')))
# Out:
# channelGrouping
# browser
# deviceCategory
# operatingSystem
# city
# continent
# country
# metro
# networkDomain
# region
# subContinent
# adContent
# adwordsClickInfo.adNetworkType
# adwordsClickInfo.gclId
# adwordsClickInfo.page
# adwordsClickInfo.slot
# campaign
# keyword
# medium
# referralPath
# source
# adwordsClickInfo.isVideoAd
# isTrueDirect

# %%
for col in cat_cols:
    print(col)
    lblt = LabelEncoder()
    lblt.fit(list(test_df[col].values.astype('str'))) # + list(test_df[col].values.astype('str')))
    test_df[col] = lblt.transform(list(test_df[col].values.astype('str')))
# Out:
# channelGrouping
# browser
# deviceCategory
# operatingSystem
# city
# continent
# country
# metro
# networkDomain
# region
# subContinent
# adContent
# adwordsClickInfo.adNetworkType
# adwordsClickInfo.gclId
# adwordsClickInfo.page
# adwordsClickInfo.slot
# campaign
# keyword
# medium
# referralPath
# source
# adwordsClickInfo.isVideoAd
# isTrueDirect

# %%
num_cols = ["hits", "pageviews", "visitNumber", "visitStartTime", "bounces",  "newVisits"]    
for col in num_cols:
    train_df[col] = train_df[col].astype(float)
    # test_df[col] = test_df[col].astype(float)

# %%
num_cols = ["hits", "pageviews", "visitNumber", "visitStartTime", "bounces",  "newVisits"]    
for col in num_cols:
    test_df[col] = test_df[col].astype(float)
    # test_df[col] = test_df[col].astype(float)

# %%
from sklearn.model_selection import train_test_split

y = np.log1p(train_df["totalTransactionRevenue"].values)
X = train_df[cat_cols + num_cols + ['fullVisitorId']]

X_train_full, X_test_full, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

X_train = X_train_full[cat_cols + num_cols]
X_test = X_test_full[cat_cols + num_cols]
# Out:
# C:\Python\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log1p
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X_pred = test_df[cat_cols + num_cols]

# %%
def run_lgb(train_X, train_y, val_X, val_y):
    params = {
        "objective" : "regression",
        "metric" : "rmse", 
        "num_leaves" : 30,
        "min_child_samples" : 100,
        "learning_rate" : 0.1,
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.5,
        "bagging_frequency" : 5,
        "bagging_seed" : 2018,
        "verbosity" : -1
    }
    
    lgtrain = lgb.Dataset(train_X, label=train_y)
    lgval = lgb.Dataset(val_X, label=val_y)
    model = lgb.train(params, lgtrain, 1000, valid_sets=[lgval], early_stopping_rounds=100, verbose_eval=100)

    # pred_test_y = model.predict(test_X, num_iteration=model.best_iteration)
    pred_val_y = model.predict(val_X, num_iteration=model.best_iteration)
    return model, pred_val_y #pred_test_y

# %%
#!pip install lightgbm
import lightgbm as lgb

# %%
model, pred_val = run_lgb(X_train, y_train, X_test, y_test)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 1.53667
# [200]	valid_0's rmse: 1.53268
# [300]	valid_0's rmse: 1.53016
# [400]	valid_0's rmse: 1.53066
# Early stopping, best iteration is:
# [301]	valid_0's rmse: 1.53016

# %%
from sklearn import metrics
pred_val[pred_val<0] = 0
val_pred_df = pd.DataFrame({"fullVisitorId":X_test_full["fullVisitorId"].values})
val_pred_df["totalTransactionRevenue"] = y_test # X_test_full["totals.transactionRevenue"].values
val_pred_df["PredictedRevenue"] = np.expm1(pred_val)
#print(np.sqrt(metrics.mean_squared_error(np.log1p(val_pred_df["transactionRevenue"].values), np.log1p(val_pred_df["PredictedRevenue"].values))))
val_pred_df = val_pred_df.groupby("fullVisitorId")["totalTransactionRevenue", "PredictedRevenue"].sum().reset_index()
print(np.sqrt(metrics.mean_squared_error(np.log1p(val_pred_df["totalTransactionRevenue"].values), np.log1p(val_pred_df["PredictedRevenue"].values))))
# Out:
# 0.9317370810390099

# %%
train_df.to_csv("gtrain_df.csv")

# %%
test_df.to_csv("gtest_df.csv")

# %%
def run_lgb_test(train_X, train_y, val_X, val_y, test_X):
    params = {
        "objective" : "regression",
        "metric" : "rmse", 
        "num_leaves" : 30,
        "min_child_samples" : 100,
        "learning_rate" : 0.1,
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.5,
        "bagging_frequency" : 5,
        "bagging_seed" : 2018,
        "verbosity" : -1
    }
    
    lgtrain = lgb.Dataset(train_X, label=train_y)
    lgval = lgb.Dataset(val_X, label=val_y)
    model = lgb.train(params, lgtrain, 1000, valid_sets=[lgval], early_stopping_rounds=100, verbose_eval=100)

    pred_test_y = model.predict(test_X, num_iteration=model.best_iteration)
    pred_val_y = model.predict(val_X, num_iteration=model.best_iteration)
    return model, pred_val_y,pred_test_y

# %%
model, pred_val, pred_test = run_lgb_test(X_train, y_train, X_test, y_test, X_pred)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 1.53667
# [200]	valid_0's rmse: 1.53268
# [300]	valid_0's rmse: 1.53016
# [400]	valid_0's rmse: 1.53066
# Early stopping, best iteration is:
# [301]	valid_0's rmse: 1.53016

# %%
pred_test[:10]
# Out:
# array([ 0.18775855,  0.03013715,  0.40306058,  0.04037648,  0.12626826,
#         0.33085493, -0.11940742,  0.59287516,  0.0154465 , -0.00523943])

# %%
test_pred_df = pd.DataFrame({"fullVisitorId":test_df["fullVisitorId"].values})
#test_pred_df["totalTransactionRevenue"] = y_test # X_test_full["totals.transactionRevenue"].values
test_pred_df["PredictedRevenue"] = np.expm1(pred_test)
test_pred_df_group = test_pred_df.groupby("fullVisitorId")["PredictedRevenue"].sum().reset_index()

# %%
test_pred_df_group.head()
# Out:
#     fullVisitorId  PredictedRevenue
# 0   1995526696366         -0.074732
# 1  16367580689231         -0.016634
# 2  18966949534117         -0.062816
# 3  24844201502183          0.100632
# 4  24845665201193         -0.023315

# %%
test_pred_df.head()
# Out:
#          fullVisitorId  PredictedRevenue
# 0  7460955084541987166          0.206542
# 1   460252456180441002          0.030596
# 2  3461808543879602873          0.496398
# 3   975129477712150630          0.041203
# 4  8381672768065729990          0.134586

# %%
prediction = pd.DataFrame({"fullVisitorId": test_pred_df_group.fullVisitorId,
                           "PredictedLogRevenue":test_pred_df_group.PredictedRevenue})

# %%
prediction.to_csv("Grev_pred1.csv")
